# %% [markdown]
# <a href="https://colab.research.google.com/github/Shakib-4236/Artificial-Intelligence_Basic-Python/blob/main/Artificial_Intelligence_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv('PriceDataSet.csv')
df.dropna()
print(df.to_string())
# Out:
#     weight  price
# 0        1     10
# 1        2     20
# 2        3     25
# 3        4     40
# 4        5     45
# 5        6     75
# 6        7     90
# 7        8    100
# 8        9    115
# 9       10    120
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
df.head(10)
# Out:
#    weight  price
# 0       1     10
# 1       2     20
# 2       3     25
# 3       4     40
# 4       5     45
# 5       6     75
# 6       7     90
# 7       8    100
# 8       9    115
# 9      10    120

# %%
df.tail(8)
# Out:
#     weight  price
# 7        8    100
# 8        9    115
# 9       10    120
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165

# %%
df.corr()
# Out:
#           weight     price
# weight  1.000000  0.989168
# price   0.989168  1.000000

# %%
import matplotlib.pyplot as plt
df.plot(kind = 'scatter', x='weight', y = 'price')
plt.xlabel("Weight of Potato")
plt.ylabel("Price of Potato")
plt.title("Price Prediction")
plt.show()

# %%
df["weight"].plot(kind = 'hist')
plt.show()

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv('A - Copy.csv')
print(df.to_string())
# Out:
#     weight  price
# 0      1.0     10
# 1      2.0     20
# 2      3.0     25
# 3      NaN     40
# 4      5.0     45
# 5      6.0     75
# 6      7.0     90
# 7      8.0    100
# 8      9.0    115
# 9     10.0    120
# 10    11.0    130
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165

# %%
new_df=df.dropna()
print(new_df)
# Out:
#     weight  price
# 0      1.0     10
# 1      2.0     20
# 2      3.0     25
# 4      5.0     45
# 5      6.0     75
# 6      7.0     90
# 7      8.0    100
# 8      9.0    115
# 9     10.0    120
# 10    11.0    130
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165

# %%
new_df=df.fillna(11)
print(new_df)
# Out:
#     weight  price
# 0      1.0     10
# 1      2.0     20
# 2      3.0     25
# 3     11.0     40
# 4      5.0     45
# 5      6.0     75
# 6      7.0     90
# 7      8.0    100
# 8      9.0    115
# 9     10.0    120
# 10    11.0    130
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165

# %%
x=df['weight'].mean()
new_df=df.fillna(x)
print(new_df)
print(df.duplicated())
# Out:
#        weight  price
# 0    1.000000     10
# 1    2.000000     20
# 2    3.000000     25
# 3    8.285714     40
# 4    5.000000     45
# 5    6.000000     75
# 6    7.000000     90
# 7    8.000000    100
# 8    9.000000    115
# 9   10.000000    120
# 10  11.000000    130
# 11  12.000000    132
# 12  13.000000    140
# 13  14.000000    160
# 14  15.000000    165
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# dtype: bool

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# dtype: bool

# %%
df=pd.read_csv('B.csv')
print(df)
# Out:
#     weight  price
# 0        1     10
# 1        2     20
# 2        3     25
# 3        2     20
# 4        5     45
# 5        6     75
# 6        7     90
# 7        2     20
# 8        9    115
# 9       10    120
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      20     20

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# dtype: bool

# %%
df=df.drop_duplicates()
print(df)
# Out:
#     weight  price
# 0        1     10
# 1        2     20
# 2        3     25
# 4        5     45
# 5        6     75
# 6        7     90
# 8        9    115
# 9       10    120
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      20     20

# %%
df.describe()
# Out:
#           weight       price
# count  13.000000   13.000000
# mean    8.692308   83.230769
# std     5.421940   53.516592
# min     1.000000   10.000000
# 25%     5.000000   25.000000
# 50%     9.000000   90.000000
# 75%    12.000000  130.000000
# max    20.000000  160.000000
